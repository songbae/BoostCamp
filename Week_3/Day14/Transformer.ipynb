# %% [markdown]
# ## Transformer
# ---
# - Transformer is the first sequence transduction model based entirely on attention
#
# - From a bird's-eye view, this is what the Transformer does for machine translation tasks
#
# ```
# self-attention : in both encoder and decoder is the cornerstone of Transformer
#
# First, we represent each word with some embedding
#
# Then, Transformer encodes each word to feature vectors with Self-Attention
#
# Suppose: The animal didn't cross the street because it was too tired
#
# Input
#
# embedding
#
# Queries
#
# Keys
#
# Values
#
# Score-> then we need to compute the score per each word
#
# ```
#
# - Calaulating Q,K and V from X in a matrix from
#
# ---
#
# `Multi-headed attention(MHA) allows Transformer to focus on different posiotions`
